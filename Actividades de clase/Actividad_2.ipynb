# %%
#mi intento
Impares=[]
Pares=[]

for i in range(len("Estrategias")):
    if i%3 == 0:
        Impares.append("Estrategias"[i])     # Se puede decir que dio pero no lo que se pedia esactmente XD
    elif i%2 == 1:
        Pares.append("Universidad"[i])

suma=Impares+Pares
print(str(suma))
# Out:
# ['E', 'r', 'e', 'a', 'n', 'r', 'i']

# %%
#Corregido
a="Universidad"
b="Estrategias"
arreglo=[]

for i in range(len(a)):
  if i%2==0:
    arreglo.append(a[i])
  else:
    arreglo.append(b[i])
print(arreglo)
# Out:
# ['U', 's', 'i', 'r', 'e', 't', 's', 'g', 'd', 'a', 'd']

# %%
#Corregido
a="Universidad"
b="Estrategias"
arreglo=[]

for i in range(len(a)):
  if i%2==0:
    arreglo.append(a[i])
  else:
    arreglo.append(b[i])
print(arreglo)
arreglo[3] = "y"
arreglo[6] = "x"
arreglo[9] = "o"

print(arreglo)
# Out:
# ['U', 's', 'i', 'r', 'e', 't', 's', 'g', 'd', 'a', 'd']
# ['U', 's', 'i', 'y', 'e', 't', 'x', 'g', 'd', 'o', 'd']
